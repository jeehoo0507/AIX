# %% [markdown]
# # Convolutional Neural Networks I

# %% [markdown]
# #### Reference
# Joonseok Lee. (2026). *Lecture 5. Convolutional Neural Networks I* [Video]. YouTube.
# link : [url](https://www.youtube.com/watch?v=uTnxnbCictM&list=PL0E_1UqNACXABu9ft6PTRKaIvydxHJ9_w&index=5&t=1051s)
